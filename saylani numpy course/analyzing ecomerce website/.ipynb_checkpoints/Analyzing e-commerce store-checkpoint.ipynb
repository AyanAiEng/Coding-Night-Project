# %%
import numpy as np

# %%
file_1 = np.loadtxt(r"C:\Users\Ashar\Downloads\salani IT Course\saylani numpy course\analyzing ecomerce website\product.csv", delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 file_1 = np.loadtxt(r"C:\Users\Ashar\Downloads\salani IT Course\saylani numpy course\analyzing ecomerce website\product.csv", delimiter=",")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1396             converters=converters, skiplines=skiprows, usecols=usecols,
#    1397             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1398             max_rows=max_rows, quote=quotechar)
#    1400 return arr
#
# ...

# %%
import os
path = r"C:\Users\Ashar\Downloads\salani IT Course\saylani numpy course\analyzing ecomerce website\product.csv"
print(os.path.exists(path))
# Out:
# True
