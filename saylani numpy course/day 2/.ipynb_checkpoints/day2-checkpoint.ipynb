# %%
import numpy as np
from numpy import random

# %%
my_list = [1,2,3,4,5,6,7,8,55,54,56]
type(my_list)
# Out:
# list

# %% [raw]
# np_array = np.array(my_list)
# np_array.dtype

# %%
np_array1 = np.random.randint(0,10, size = (10,10))
np_array1 = np_array1*3
print(np_array1)
# Out:
# [[24  9 21 27 18 15 12 24  9  3]
#  [24  3 15 24 21  9 27 21 15  3]
#  [ 6 18 18  9  0 15  3 18 24 27]
#  [ 3 21 15 12  6  3 21  6 15 21]
#  [24 18 21 21 15 21 15 18 12 27]
#  [ 0  9 18  6  6 21  3 15 27 21]
#  [21 27  9 12 15  3 18  6 18 18]
#  [ 6 12  9 24  9 18  6  0  3 24]
#  [21 24 18 15 12 27  3 24  3 18]
#  [27  9 15 21 18 12 24 12  9 18]]

# %%
np_array1[(np_array1%2 == 0)]
# Out:
# array([12, 18,  0, 12, 24, 24, 24,  6, 18,  6, 12, 12,  6,  6,  6, 24, 12,
#        12, 18,  6, 24, 18,  6, 24, 12,  0,  6,  6, 24, 18,  0, 18,  6, 12,
#        24, 24,  0, 24,  6,  0,  6, 18, 24,  0,  6,  6, 18,  6, 18],
#       dtype=int32)

# %%
np_array1[(np_array1%2 != 0)].size
# Out:
# 55

# %%
np_array1.size
# Out:
# 100
